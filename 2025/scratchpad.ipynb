# %% [markdown]
# Test med map()
#
# ```python
# v = tuple(map(int, s.split("-")))
# ````
#
# ersätter
#
# ```python
# parts = s.split("-")
# a = int(parts[0])
# b = int(parts[1])
# v = (a, b)
# ```

# %%
s = "1-9"
for v in map(int, s.split("-")):
    print(v)
    print(type(v))

v = tuple(map(int, s.split("-")))
print(v)
# Out:
# 1
# <class 'int'>
# 9
# <class 'int'>
# (1, 9)

# %% [markdown]
# Kunde också ha varit:
# ```python
# tuple(int(x) for x in s.split("-"))
# ```
